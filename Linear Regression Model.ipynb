# %%
import numpy as np 
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
import seaborn as sn

# %%
df22 = pd.read_csv("2022.csv")
df21 = pd.read_csv("2021.csv")
df20 = pd.read_csv("2020.csv")
df19 = pd.read_csv("2019.csv")
df18 = pd.read_csv("2018.csv")
df17 = pd.read_csv("2017.csv")
df16 = pd.read_csv("2016.csv")
df15 = pd.read_csv("2015.csv")

# %%
df22.rename(columns={"Happiness score":"Happiness Score",
                     "Explained by: GDP per capita":"GDP per capita",
                     "Explained by: Social support":"Social support",
                     "Explained by: Healthy life expectancy":"Healthy life expectancy",
                     "Explained by: Freedom to make life choices":"Freedom",
                     "Explained by: Generosity":"Generosity",
                     "Explained by: Perceptions of corruption":"Trust"
                    }, inplace = True)
df22["Year"]=2022
df22.drop(["Whisker-high","Whisker-low","Dystopia (1.83) + residual","RANK"], axis=1, inplace=False)
# Out:
#          Country  Happiness Score  GDP per capita  Social support  \
# 0        Finland            7.821           1.892           1.258
# 1        Denmark            7.636           1.953           1.243
# 2        Iceland            7.557           1.936           1.320
# 3    Switzerland            7.512           2.026           1.226
# 4    Netherlands            7.415           1.945           1.206
# ..           ...              ...             ...             ...
# 141    Botswana*            3.471           1.503           0.815
# 142      Rwanda*            3.268           0.785           0.133
# 143     Zimbabwe            2.995           0.947           0.690
# 144      Lebanon            2.955           1.392           0.498
# 145  Afghanistan            2.404           0.758           0.000
#
#      Healthy life expectancy  Freedom  Generosity  Trust  Year
# 0                      0.775    0.736       0.109  0.534  2022
# ...

# %%
df21.rename(columns={"Ladder score":"Happiness Score",
                     "Country name": "Country",
                     "Logged GDP per capita":"GDP per capita",
                     "Freedom to make life choices":"Freedom",
                     "Explained by: Generosity":"Generosity",
                     "Perceptions of corruption":"Trust"
                    }, inplace = True)
df21["Year"]=2021
df21.drop(["Regional indicator","upperwhisker","lowerwhisker","Standard error of ladder score","Ladder score in Dystopia","Explained by: Log GDP per capita","Explained by: Social support","Explained by: Healthy life expectancy","Explained by: Freedom to make life choices","Generosity","Explained by: Perceptions of corruption","Dystopia + residual"], axis=1, inplace=False)
# Out:
#          Country  Happiness Score  GDP per capita  Social support  \
# 0        Finland            7.842          10.775           0.954
# 1        Denmark            7.620          10.933           0.954
# 2    Switzerland            7.571          11.117           0.942
# 3        Iceland            7.554          10.878           0.983
# 4    Netherlands            7.464          10.932           0.942
# ..           ...              ...             ...             ...
# 144      Lesotho            3.512           7.926           0.787
# 145     Botswana            3.467           9.782           0.784
# 146       Rwanda            3.415           7.676           0.552
# 147     Zimbabwe            3.145           7.943           0.750
# 148  Afghanistan            2.523           7.695           0.463
#
#      Healthy life expectancy  Freedom  Trust  Year
# 0                     72.000    0.949  0.186  2021
# 1                     72.700    0.946  0.179  2021
# ...

# %%
df20.rename(columns={"Ladder score":"Happiness Score",
                     "Country name": "Country",
                     "Logged GDP per capita":"GDP per capita",
                     "Freedom to make life choices":"Freedom",
                     "Explained by: Generosity":"Generosity",
                     "Perceptions of corruption":"Trust"
                    }, inplace = True)
df20["Year"]=2020
df20.drop(["Regional indicator","upperwhisker","lowerwhisker","Standard error of ladder score","Ladder score in Dystopia","Explained by: Log GDP per capita","Explained by: Social support","Explained by: Healthy life expectancy","Explained by: Freedom to make life choices","Generosity","Explained by: Perceptions of corruption","Dystopia + residual"], axis=1, inplace=False)
# Out:
#                       Country  Happiness Score  GDP per capita  \
# 0                     Finland           7.8087       10.639267
# 1                     Denmark           7.6456       10.774001
# 2                 Switzerland           7.5599       10.979933
# 3                     Iceland           7.5045       10.772559
# 4                      Norway           7.4880       11.087804
# ..                        ...              ...             ...
# 148  Central African Republic           3.4759        6.625160
# 149                    Rwanda           3.3123        7.600104
# 150                  Zimbabwe           3.2992        7.865712
# 151               South Sudan           2.8166        7.425360
# 152               Afghanistan           2.5669        7.462861
#
#      Social support  Healthy life expectancy   Freedom     Trust  Year
# 0          0.954330                71.900825  0.949172  0.195445  2020
# ...

# %%
df19.rename(columns={"Freedom to make life choices":"Freedom",
                     "Score":"Happiness Score",
                     "Country or region":"Country",
                     "Perceptions of corruption":"Trust"
                    }, inplace = True)
df19["Year"]=2019
df19.drop(["Overall rank"], axis=1, inplace=False)
# Out:
#                       Country  Happiness Score  GDP per capita  \
# 0                     Finland            7.769           1.340
# 1                     Denmark            7.600           1.383
# 2                      Norway            7.554           1.488
# 3                     Iceland            7.494           1.380
# 4                 Netherlands            7.488           1.396
# ..                        ...              ...             ...
# 151                    Rwanda            3.334           0.359
# 152                  Tanzania            3.231           0.476
# 153               Afghanistan            3.203           0.350
# 154  Central African Republic            3.083           0.026
# 155               South Sudan            2.853           0.306
#
#      Social support  Healthy life expectancy  Freedom  Generosity  Trust  Year
# 0             1.587                    0.986    0.596       0.153  0.393  2019
# ...

# %%
df18.rename(columns={"Freedom to make life choices":"Freedom",
                     "Score":"Happiness Score",
                     "Country or region":"Country",
                     "Perceptions of corruption":"Trust"
                    }, inplace = True)
df18["Year"]=2018
df18.drop(["Overall rank"], axis=1, inplace=False)
# Out:
#                       Country  Happiness Score  GDP per capita  \
# 0                     Finland            7.632           1.305
# 1                      Norway            7.594           1.456
# 2                     Denmark            7.555           1.351
# 3                     Iceland            7.495           1.343
# 4                 Switzerland            7.487           1.420
# ..                        ...              ...             ...
# 151                     Yemen            3.355           0.442
# 152                  Tanzania            3.303           0.455
# 153               South Sudan            3.254           0.337
# 154  Central African Republic            3.083           0.024
# 155                   Burundi            2.905           0.091
#
#      Social support  Healthy life expectancy  Freedom  Generosity  Trust  Year
# 0             1.592                    0.874    0.681       0.202  0.393  2018
# ...

# %%
df17.rename(columns={"Happiness.Score":"Happiness Score",
                     "Economy..GDP.per.Capita.":"GDP per capita",
                     "Family":"Social support",
                     "Health..Life.Expectancy.":"Healthy life expectancy",
                     "Trust..Government.Corruption.":"Trust"
                    }, inplace = True)
df17["Year"]=2017
df17.drop(["Whisker.high","Whisker.low","Dystopia.Residual","Happiness.Rank"], axis=1, inplace=False)
# Out:
#                       Country  Happiness Score  GDP per capita  \
# 0                      Norway            7.537        1.616463
# 1                     Denmark            7.522        1.482383
# 2                     Iceland            7.504        1.480633
# 3                 Switzerland            7.494        1.564980
# 4                     Finland            7.469        1.443572
# ..                        ...              ...             ...
# 150                    Rwanda            3.471        0.368746
# 151                     Syria            3.462        0.777153
# 152                  Tanzania            3.349        0.511136
# 153                   Burundi            2.905        0.091623
# 154  Central African Republic            2.693        0.000000
#
#      Social support  Healthy life expectancy   Freedom  Generosity     Trust  \
# 0          1.533524                 0.796667  0.635423    0.362012  0.315964
# ...

# %%
df16.rename(columns={"Economy (GDP per Capita)":"GDP per capita",
                     "Family":"Social support",
                     "Health (Life Expectancy)":"Healthy life expectancy",
                     "Trust (Government Corruption)":"Trust"
                    }, inplace = True)
df16["Year"]=2016
df16.drop(["Region","Lower Confidence Interval","Upper Confidence Interval","Dystopia Residual","Happiness Rank"], axis=1, inplace=False)
# Out:
#          Country  Happiness Score  GDP per capita  Social support  \
# 0        Denmark            7.526         1.44178         1.16374
# 1    Switzerland            7.509         1.52733         1.14524
# 2        Iceland            7.501         1.42666         1.18326
# 3         Norway            7.498         1.57744         1.12690
# 4        Finland            7.413         1.40598         1.13464
# ..           ...              ...             ...             ...
# 152        Benin            3.484         0.39499         0.10419
# 153  Afghanistan            3.360         0.38227         0.11037
# 154         Togo            3.303         0.28123         0.00000
# 155        Syria            3.069         0.74719         0.14866
# 156      Burundi            2.905         0.06831         0.23442
#
#      Healthy life expectancy  Freedom    Trust  Generosity  Year
# 0                    0.79504  0.57941  0.44453     0.36171  2016
# ...

# %%
df15.rename(columns={"Economy (GDP per Capita)":"GDP per capita",
                     "Family":"Social support",
                     "Health (Life Expectancy)":"Healthy life expectancy",
                     "Trust (Government Corruption)":"Trust"
                    }, inplace = True)
df15["Year"] = 2015

df15.drop(["Region","Standard Error","Dystopia Residual","Happiness Rank"], axis=1, inplace=False)
# Out:
#          Country  Happiness Score  GDP per capita  Social support  \
# 0    Switzerland            7.587         1.39651         1.34951
# 1        Iceland            7.561         1.30232         1.40223
# 2        Denmark            7.527         1.32548         1.36058
# 3         Norway            7.522         1.45900         1.33095
# 4         Canada            7.427         1.32629         1.32261
# ..           ...              ...             ...             ...
# 153       Rwanda            3.465         0.22208         0.77370
# 154        Benin            3.340         0.28665         0.35386
# 155        Syria            3.006         0.66320         0.47489
# 156      Burundi            2.905         0.01530         0.41587
# 157         Togo            2.839         0.20868         0.13995
#
#      Healthy life expectancy  Freedom    Trust  Generosity  Year
# 0                    0.94143  0.66557  0.41978     0.29678  2015
# ...

# %% [markdown]
# # Distribution

# %%
df22.hist(figsize= (20,20))
plt.show()

# %% [markdown]
# # Trend of overall happiness score

# %%
scoresummary = df22.describe()[['Happiness Score']]
scoresummary['2015'] = df15.describe()[['Happiness Score']]
scoresummary.drop(columns=['Happiness Score'],axis=1, inplace=True)
scoresummary['2016'] = df16.describe()[['Happiness Score']]
scoresummary['2017'] = df17.describe()[['Happiness Score']]
scoresummary['2018'] = df18.describe()[['Happiness Score']]
scoresummary['2019'] = df19.describe()[['Happiness Score']]
scoresummary['2020'] = df20.describe()[['Happiness Score']]
scoresummary['2021'] = df21.describe()[['Happiness Score']]
scoresummary['2022'] = df22.describe()[['Happiness Score']]
scoresummary.drop('std', inplace=True)
scores = scoresummary.transpose()
scores
# Out:
#       count      mean     min      25%     50%      75%     max
# 2015  158.0  5.375734  2.8390  4.52600  5.2325  6.24375  7.5870
# 2016  157.0  5.382185  2.9050  4.40400  5.3140  6.26900  7.5260
# 2017  155.0  5.354019  2.6930  4.50550  5.2790  6.10150  7.5370
# 2018  156.0  5.375917  2.9050  4.45375  5.3780  6.16850  7.6320
# 2019  156.0  5.407096  2.8530  4.54450  5.3795  6.18450  7.7690
# 2020  153.0  5.473240  2.5669  4.72410  5.5150  6.22850  7.8087
# 2021  149.0  5.532839  2.5230  4.85200  5.5340  6.25500  7.8420
# 2022  146.0  5.553575  2.4040  4.88875  5.5685  6.30500  7.8210

# %%
scores['min'].plot()
scores['mean'].plot()
scores['max'].plot()
plt.title('Happiness Score')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(15,8))
sns.lineplot(data = df22[:10], x = "Country", y = "GDP per capita", marker = 'o', label = 'GDP per capita')
sns.lineplot(data = df22[:10], x = "Country", y = "Social support", marker = 'o', label = 'Social support')
sns.lineplot(data = df22[:10], x = "Country", y = "Healthy life expectancy", marker = 'o', label = 'Healthy life expectancy')
sns.lineplot(data = df22[:10], x = "Country", y = "Freedom", marker = 'o', label = 'Freedom to make life choices')
sns.lineplot(data = df22[:10], x = "Country", y = "Trust", marker = 'o', label = 'Perception of corruption')
sns.lineplot(data = df22[:10], x = "Country", y = "Generosity", marker = 'o', label = 'Generosity')
plt.ylabel('Values')
plt.title('Line plot for top 10 countries statistics')
plt.legend()
plt.show()

# %% [markdown]
# # Correlation

# %%
indep = df22.drop(['RANK','Happiness Score','Country','Whisker-high','Whisker-low',"Year"], axis=1, inplace=False)
plt.figure(figsize=(10,8))
corrMatrix = indep.corr()
sn.heatmap(corrMatrix,annot=True)
plt.show()

# %%
c1 = df22.drop(['RANK','Whisker-high','Whisker-low',"Year"], axis=1, inplace=False)
corr = c1.corr()
plt.figure(figsize = [7,5])
sn.barplot(y = corr['Happiness Score'].index, x = corr['Happiness Score'])
plt.title("Correlation", fontsize= 15,fontweight="bold")
plt.ylabel("Attributes")
plt.xlabel("Happiness score")
# Out:
# Text(0.5, 0, 'Happiness score')

# %%
cor_target = abs(corr['Happiness Score'])
cor_target
# Out:
# Happiness Score               1.000000
# Dystopia (1.83) + residual    0.498990
# GDP per capita                0.763677
# Social support                0.777889
# Healthy life expectancy       0.740260
# Freedom                       0.624822
# Generosity                    0.063785
# Trust                         0.416216
# Name: Happiness Score, dtype: float64

# %% [markdown]
# # Hypothesis Testing & Linear Regression

# %%
df22.columns = df22.columns.str.replace(" ","_")

# %%
import statsmodels.formula.api as smf
model1 = smf.ols(formula = "Happiness_Score ~ GDP_per_capita + Social_support + Healthy_life_expectancy + Freedom + Trust + Generosity", data = df22).fit()
print(model1.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:        Happiness_Score   R-squared:                       0.774
# Model:                            OLS   Adj. R-squared:                  0.764
# Method:                 Least Squares   F-statistic:                     79.20
# Date:                Tue, 05 Apr 2022   Prob (F-statistic):           2.16e-42
# Time:                        21:03:55   Log-Likelihood:                -110.36
# No. Observations:                 146   AIC:                             234.7
# Df Residuals:                     139   BIC:                             255.6
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# Intercept                   1.6677      0.205      8.117      0.000       1.261       2.074
# ...

# %%
model2 = smf.ols(formula = "Happiness_Score ~ Social_support + Healthy_life_expectancy + Freedom ", data = df22).fit()
print(model2.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:        Happiness_Score   R-squared:                       0.750
# Model:                            OLS   Adj. R-squared:                  0.745
# Method:                 Least Squares   F-statistic:                     142.3
# Date:                Tue, 05 Apr 2022   Prob (F-statistic):           1.32e-42
# Time:                        21:03:56   Log-Likelihood:                -117.50
# No. Observations:                 146   AIC:                             243.0
# Df Residuals:                     142   BIC:                             254.9
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# Intercept                   1.7864      0.194      9.232      0.000       1.404       2.169
# ...
